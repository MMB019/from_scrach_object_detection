# %%
pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.12.0+cu113)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (0.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13417, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 13417 (delta 24), reused 37 (delta 17), pack-reused 13368
# Receiving objects: 100% (13417/13417), 12.08 MiB | 28.36 MiB/s, done.
# Resolving deltas: 100% (9351/9351), done.

# %%
cd yolov5

# %%
# !pip install -r requirements.txt

# %%
#!cd & pip install -r requirements.txt

# %%
import torch
import matplotlib.pyplot as plt 
import numpy as np
import cv2

# %%
model=torch.hub.load("ultralytics/yolov5","yolov5s")
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-5-16 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
img = 'https://i.gaw.to/content/photos/38/40/384006_Vous_n_etes_pas_pris_dans_le_trafic.jpg'  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
# Out:
# image 1/1: 1200x1920 5 persons, 28 cars, 2 buss, 2 trucks
# Speed: 2017.1ms pre-process, 326.6ms inference, 9.3ms NMS per image at shape (1, 3, 416, 640)

# %%
print(results.render())
# Out:
# [array([[[183, 183, 191],
#         [182, 182, 190],
#         [181, 181, 189],
#         ...,
#         [185, 185, 193],
#         [185, 185, 195],
#         [185, 185, 195]],
#
#        [[183, 183, 191],
#         [182, 182, 190],
#         [181, 181, 189],
#         ...,
#         [187, 187, 195],
#         [186, 186, 196],
#         [185, 185, 195]],
#
#        [[183, 183, 191],
#         [183, 183, 191],
#         [183, 183, 191],
#         ...,
#         [187, 187, 195],
#         [185, 185, 195],
#         [183, 183, 193]],
#
#        ...,
#
#        [[255, 112,  31],
#         [255, 112,  31],
#         [255, 112,  31],
#         ...,
#         [ 18,  27,  58],
#         [  6,  15,  44],
#         [  1,  11,  38]],
#
#        [[255, 112,  31],
#         [255, 112,  31],
#         [255, 112,  31],
#         ...,
#         [ 17,  26,  57],
#         [  6,  16,  43],
#         [  2,  12,  39]],
#
#        [[145, 143, 146],
#         [ 87,  85,  86],
#         [ 32,  31,  29],
#         ...,
#         [ 17,  26,  57],
#         [ 10,  20,  47],
#         [  7,  17,  44]]], dtype=uint8)]

# %%
p_n=0


for i,el in enumerate(results.crop()):
  if el['label'].split(" ")[0] in ['person','car','bird','cat','dog','horse','sheep','cow']:
    print("bonjour")
    print(el['label'])
    p_n=p_n+1
    
    print(i)


print("nombre de personne ",p_n)
# Out:
# Saved 1 image to runs/detect/exp
# Saved results to runs/detect/exp
# bonjour
# car 0.28
# 1
# bonjour
# person 0.28
# 2
# bonjour
# car 0.30
# 3
# bonjour
# car 0.31
# 4
# bonjour
# car 0.33
# 5
# bonjour
# car 0.34
# 6
# bonjour
# car 0.35
# 7
# bonjour
# person 0.35
# 8
# bonjour
# car 0.37
# 10
# bonjour
# car 0.38
# 11
# bonjour
# car 0.38
# 12
# bonjour
# car 0.40
# 13
# bonjour
# car 0.41
# 14
# bonjour
# car 0.41
# 15
# bonjour
# car 0.43
# 16
# bonjour
# car 0.44
# 17
# bonjour
# car 0.45
# 18
# bonjour
# car 0.45
# 19
# bonjour
# car 0.46
# 20
# bonjour
# car 0.48
# 21
# bonjour
# car 0.48
# 22
# bonjour
# car 0.53
# 23
# bonjour
# car 0.54
# 24
# bonjour
# person 0.58
# 25
# bonjour
# car 0.59
# 26
# bonjour
# car 0.63
# 27
# bonjour
# car 0.70
# 28
# bonjour
# car 0.72
# 29
# bonjour
# person 0.78
# 30
# bonjour
# car 0.78
# 31
# bonjour
# person 0.79
# 32
# bonjour
# car 0.81
# 34
# bonjour
# car 0.84
# 36
# nombre de personne  33

# %%
results.crop()[0]['label']
# Out:
# Saved 1 image to runs/detect/exp2
# Saved results to runs/detect/exp2
# 'truck 0.27'

# %%
# %matplotlib inline
plt.figure(figsize=(12,8))
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap=cv2.VideoCapture(-1)
while cap.isOpened():
    rect,frame=cap.read()
    results=model(frame)
    
    cv2.imshow("YOLOV",np.squeeze(results.render()))
    if cv2.waitKey(10)& 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# #Training from scrach

# %%
import uuid #unique identifier
import os
import time
from google.colab.patches import cv2_imshow

# %%
IMAGE_PATH=os.path.join("data","images")
labels=["masque","denude"]
number_img=20

# %%
cap=cv2.VideoCapture(0)
for label in labels:
  print(f"collection of data: {label}")
  time.sleep(5)
  for nb in range(number_img):
    print(f"collection of data: {label} and number {nb}")

    rect,frame=cap.read()
    imgname=os.path.join(IMAGE_PATH,label+'.'+str(uuid.uuid1())+".jpg")
    cv2.imwrite(imgname,frame)
    cv2_imshow(frame)
    time.sleep(2)
    if cv2.waitKey(10)& 0xFF==ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# collection of data: masque
# collection of data: masque and number 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b9505567b111> in <module>()
#       9     imgname=os.path.join(IMAGE_PATH,label+'.'+str(uuid.uuid1())+".jpg")
#      10     cv2.imwrite(imgname,frame)
# ---> 11     cv2_imshow(frame)
#      12     time.sleep(2)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
for label in labels:
  print(f"collection of data: {label}")
  time.sleep(5)
  for nb in range(number_img):
    print(f"collection of data: {label} and number {nb}")
    imgname=os.path.join(IMAGE_PATH,label+'.'+str(uuid.uuid1())+".jpg")
    print(imgname)
# Out:
# collection of data: masque
# collection of data: masque and number 0
# data/images/masque.f25a0ee0-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 1
# data/images/masque.f25a236c-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 2
# data/images/masque.f25a3406-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 3
# data/images/masque.f25a47e8-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 4
# data/images/masque.f25a5526-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 5
# data/images/masque.f25a5742-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 6
# data/images/masque.f25a5904-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 7
# data/images/masque.f25a5ab2-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 8
# data/images/masque.f25a5dbe-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 9
# data/images/masque.f25a5fa8-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 10
# data/images/masque.f25a6174-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 11
# data/images/masque.f25a6336-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 12
# data/images/masque.f25a64c6-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 13
# data/images/masque.f25a6656-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 14
# data/images/masque.f25a67f0-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 15
# data/images/masque.f25a69d0-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 16
# data/images/masque.f25a6bc4-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 17
# data/images/masque.f25a6d5e-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 18
# data/images/masque.f25a6f3e-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: masque and number 19
# data/images/masque.f25a879e-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude
# collection of data: denude and number 0
# data/images/denude.f5564046-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 1
# data/images/denude.f55645a0-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 2
# data/images/denude.f5564870-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 3
# data/images/denude.f5564b18-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 4
# data/images/denude.f5564d7a-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 5
# data/images/denude.f5564ffa-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 6
# data/images/denude.f55652b6-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 7
# data/images/denude.f55655fe-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 8
# data/images/denude.f5565874-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 9
# data/images/denude.f5565aea-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 10
# data/images/denude.f5565e5a-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 11
# data/images/denude.f5566148-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 12
# data/images/denude.f55663be-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 13
# data/images/denude.f5566616-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 14
# data/images/denude.f5566850-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 15
# data/images/denude.f5566a94-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 16
# data/images/denude.f5566cf6-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 17
# data/images/denude.f5566f3a-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 18
# data/images/denude.f5567174-d50a-11ec-91d3-0242ac1c0002.jpg
# collection of data: denude and number 19
# data/images/denude.f55673fe-d50a-11ec-91d3-0242ac1c0002.jpg
